# %% [markdown]
# <a href="https://colab.research.google.com/github/KormazovaVer/REG_Expres/blob/main/Reg_exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import csv


def read_file(file_name):
    with open(file_name) as f:
        rows = csv.reader(f, delimiter=",")
        contacts_list = list(rows)
    return contacts_list


def format_number(contacts_list):
    number_pattern_raw = r'(\+7|8)(\s*)(\(*)(\d{3})(\)*)(\s*)' \
                            r'(\-*)(\d{3})(\s*)(\-*)(\d{2})(\s*)(\-*)' \
                            r'(\d{2})(\s*)(\(*)(доб)*(\.*)(\s*)(\d+)*(\)*)'
    number_pattern_new = r'+7(\4)\8-\11-\14\15\17\18\19\20'
    contacts_list_updated = list()
    for person_card in contacts_list:
        person_card_as_str = ','.join(person_card)
        formatted_person_card = re.sub(number_pattern_raw, number_pattern_new, person_card_as_str)
        person_card_as_list = formatted_person_card.split(',')
        contacts_list_updated.append(person_card_as_list)
    return contacts_list_updated


def format_full_name(contacts_list):
    name_pattern_raw = r'^([А-ЯЁа-яё]+)(\s*)(\,?)([А-ЯЁа-яё]+)' \
                       r'(\s*)(\,?)([А-ЯЁа-яё]*)(\,?)(\,?)(\,?)'
    name_pattern_new = r'\1\3\10\4\6\9\7\8'
    contacts_list_updated = list()
    for person_card in contacts_list:
        person_card_as_str = ','.join(person_card)
        formatted_person_card = re.sub(name_pattern_raw, name_pattern_new, person_card_as_str)
        person_card_as_list = formatted_person_card.split(',')
        contacts_list_updated.append(person_card_as_list)
    return contacts_list_updated


def join_duplicates(contacts_list):
    for i in contacts_list:
        for j in contacts_list:
            if i[0] == j[0] and i[1] == j[1] and i is not j:
                if i[2] is '':
                    i[2] = j[2]
                if i[3] is '':
                    i[3] = j[3]
                if i[4] is '':
                    i[4] = j[4]
                if i[5] is '':
                    i[5] = j[5]
                if i[6] is '':
                    i[6] = j[6]
    contacts_list_updated = list()
    for person_card in contacts_list:
        if person_card not in contacts_list_updated:
            contacts_list_updated.append(person_card)
    return contacts_list_updated


def write_file(contacts_list):
    with open("phonebook.csv", "w") as f:
        data_writer = csv.writer(f, delimiter=',')
        data_writer.writerows(contacts_list)


if __name__ == '__main__':
    contacts = read_file('phonebook_raw.csv')
    contacts = format_number(contacts)
    contacts = format_full_name(contacts)
    contacts = join_duplicates(contacts)
    write_file(contacts)

# %%
import pandas as pd
df = pd.read_table('phonebook_raw.csv')
df
# Out:
#   lastname,firstname,surname,organization,position,phone,email
# 0  Усольцев Олег Валентинович,,,ФНС,главный специ...
# 1  Мартиняхин Виталий Геннадьевич,,,ФНС,,+7495913...
# 2  Наркаев,Вячеслав Рифхатович,,ФНС,,8 495-913-0168,
# 3  Мартиняхин,Виталий,Геннадьевич,ФНС,cоветник от...
# 4  Лукина Ольга Владимировна,,,Минфин,,+7 (495) 9...
# 5  Паньшин Алексей Владимирович,,,Минфин,,8(495)7...
# 6  Лагунцов Иван Алексеевич,,,Минфин,,+7 (495) 91...
# 7        Лагунцов Иван,,,,,,Ivan.Laguntcov@minfin.ru

# %%
df_new = pd.read_table('phonebook.csv')
df_new
# Out:
#   lastname,firstname,surname,organization,position,phone,email
# 0  Усольцев,Олег,Валентинович,ФНС,главный специал...
# 1  Мартиняхин,Виталий,Геннадьевич,ФНС,cоветник от...
# 2  Наркаев,Вячеслав,Рифхатович,ФНС,,+7(495)913-01...
# 3  Мартиняхин,Виталий,Геннадьевич,ФНС,cоветник от...
# 4  Лукина,Ольга,Владимировна,Минфин,,+7(495)983-3...
# 5  Паньшин,Алексей,Владимирович,Минфин,,+7(495)74...
# 6  Лагунцов,Иван,Алексеевич,Минфин,,+7(495)913-11...
